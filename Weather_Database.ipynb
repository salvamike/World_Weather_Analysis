# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print('-' * 25)

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["main"]  
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | tuzha
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | oga
# Processing Record 7 of Set 1 | zhangye
# Processing Record 8 of Set 1 | richards bay
# Processing Record 9 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | vicuna
# Processing Record 14 of Set 1 | isangel
# Processing Record 15 of Set 1 | gao
# Processing Record 16 of Set 1 | mildura
# Processing Record 17 of Set 1 | fowa
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | gornozavodsk
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | moctezuma
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | sistranda
# Processing Record 25 of Set 1 | salinopolis
# Processing Record 26 of Set 1 | ossora
# Processing Record 27 of Set 1 | varva
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | buenos aires
# Processing Record 30 of Set 1 | waipawa
# Processing Record 31 of Set 1 | kavaratti
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | carquefou
# Processing Record 36 of Set 1 | teya
# Processing Record 37 of Set 1 | manturovo
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 1 | harper
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | lufilufi
# Processing Record 44 of Set 1 | olafsvik
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | gobabis
# Processing Record 47 of Set 1 | banda aceh
# Processing Record 48 of Set 1 | tutoia
# Processing Record 49 of Set 1 | zambezi
# Processing Record 50 of Set 1 | la ronge
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | puerto escondido
# Processing Record 4 of Set 2 | yumen
# Processing Record 5 of Set 2 | havre-saint-pierre
# Processing Record 6 of Set 2 | hay river
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | shepsi
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | aswan
# Processing Record 13 of Set 2 | saint-francois
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | araouane
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | batemans bay
# Processing Record 19 of Set 2 | shakawe
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | valparaiso
# Processing Record 24 of Set 2 | da nang
# Processing Record 25 of Set 2 | nome
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | monrovia
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | caravelas
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | visby
# Processing Record 45 of Set 2 | hamilton
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | oranjestad
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | galle
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | san juan
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | nefteyugansk
# Processing Record 6 of Set 3 | tecpan
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | edson
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | mercedes
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | cody
# Processing Record 15 of Set 3 | shimoda
# Processing Record 16 of Set 3 | freeport
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | jumla
# Processing Record 21 of Set 3 | kadaya
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | zhigansk
# Processing Record 24 of Set 3 | burley
# Processing Record 25 of Set 3 | luba
# Processing Record 26 of Set 3 | la ciotat
# Processing Record 27 of Set 3 | amahai
# Processing Record 28 of Set 3 | kayasula
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | shakhrinau
# City not found. Skipping...
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | kameoka
# Processing Record 34 of Set 3 | ransang
# Processing Record 35 of Set 3 | teahupoo
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 3 | chastoozerye
# City not found. Skipping...
# Processing Record 39 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | naze
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | bac giang
# Processing Record 44 of Set 3 | esso
# Processing Record 45 of Set 3 | yambio
# Processing Record 46 of Set 3 | pomezia
# Processing Record 47 of Set 3 | toguchin
# Processing Record 48 of Set 3 | lachhmangarh
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | samandag
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | acarau
# Processing Record 3 of Set 4 | alappuzha
# Processing Record 4 of Set 4 | caraballeda
# Processing Record 5 of Set 4 | norman wells
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | dikson
# Processing Record 8 of Set 4 | muyezerskiy
# Processing Record 9 of Set 4 | arraial do cabo
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | touros
# Processing Record 12 of Set 4 | popondetta
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 4 | alice springs
# Processing Record 15 of Set 4 | port-cartier
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | coihaique
# Processing Record 18 of Set 4 | grindavik
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | santa rosa
# Processing Record 22 of Set 4 | canon city
# Processing Record 23 of Set 4 | gizo
# Processing Record 24 of Set 4 | tieli
# Processing Record 25 of Set 4 | jian
# Processing Record 26 of Set 4 | nieves
# Processing Record 27 of Set 4 | sorland
# Processing Record 28 of Set 4 | camacha
# Processing Record 29 of Set 4 | port augusta
# Processing Record 30 of Set 4 | nuristan
# Processing Record 31 of Set 4 | te anau
# Processing Record 32 of Set 4 | kirakira
# Processing Record 33 of Set 4 | tabou
# Processing Record 34 of Set 4 | victoria
# Processing Record 35 of Set 4 | mbandaka
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | baykit
# Processing Record 38 of Set 4 | los alamos
# Processing Record 39 of Set 4 | jos
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | lebyazhye
# Processing Record 42 of Set 4 | sawtell
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | livingston
# Processing Record 45 of Set 4 | sao joao da barra
# Processing Record 46 of Set 4 | ambulu
# Processing Record 47 of Set 4 | thompson
# Processing Record 48 of Set 4 | bac lieu
# Processing Record 49 of Set 4 | myitkyina
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | mahibadhoo
# Processing Record 2 of Set 5 | xining
# Processing Record 3 of Set 5 | igarka
# Processing Record 4 of Set 5 | asfi
# Processing Record 5 of Set 5 | vrises
# Processing Record 6 of Set 5 | sao lourenco do sul
# Processing Record 7 of Set 5 | okato
# Processing Record 8 of Set 5 | faanui
# Processing Record 9 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 10 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 5 | letpadan
# Processing Record 12 of Set 5 | bitkine
# Processing Record 13 of Set 5 | ormara
# Processing Record 14 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | porto santo
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | abeche
# Processing Record 20 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 21 of Set 5 | oussouye
# Processing Record 22 of Set 5 | vardo
# Processing Record 23 of Set 5 | stolin
# Processing Record 24 of Set 5 | acandi
# Processing Record 25 of Set 5 | cidreira
# Processing Record 26 of Set 5 | medeiros neto
# Processing Record 27 of Set 5 | sao geraldo do araguaia
# Processing Record 28 of Set 5 | beroroha
# Processing Record 29 of Set 5 | requena
# Processing Record 30 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | ciudad bolivar
# Processing Record 33 of Set 5 | arica
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | sorong
# Processing Record 36 of Set 5 | aklavik
# Processing Record 37 of Set 5 | shingu
# Processing Record 38 of Set 5 | lupiro
# Processing Record 39 of Set 5 | santa isabel do rio negro
# Processing Record 40 of Set 5 | barrow
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | pacific grove
# Processing Record 44 of Set 5 | miquelon
# Processing Record 45 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 5 | beihai
# Processing Record 47 of Set 5 | kungurtug
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | iracoubo
# Processing Record 50 of Set 5 | san policarpo
# Processing Record 1 of Set 6 | pangody
# Processing Record 2 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 6 | oktyabrskiy
# Processing Record 4 of Set 6 | hambantota
# Processing Record 5 of Set 6 | oranjemund
# Processing Record 6 of Set 6 | anjozorobe
# Processing Record 7 of Set 6 | tromso
# Processing Record 8 of Set 6 | marsaxlokk
# Processing Record 9 of Set 6 | kjustendil
# Processing Record 10 of Set 6 | losevo
# Processing Record 11 of Set 6 | verkhoyansk
# Processing Record 12 of Set 6 | auki
# Processing Record 13 of Set 6 | strezhevoy
# Processing Record 14 of Set 6 | rabo de peixe
# Processing Record 15 of Set 6 | sosnovo-ozerskoye
# Processing Record 16 of Set 6 | ahipara
# Processing Record 17 of Set 6 | baculin
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | erzin
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | casper
# Processing Record 25 of Set 6 | asau
# Processing Record 26 of Set 6 | seoul
# Processing Record 27 of Set 6 | dryden
# Processing Record 28 of Set 6 | santa lucia
# Processing Record 29 of Set 6 | qasigiannguit
# Processing Record 30 of Set 6 | nianzishan
# Processing Record 31 of Set 6 | ranau
# Processing Record 32 of Set 6 | aktanysh
# Processing Record 33 of Set 6 | quang ngai
# Processing Record 34 of Set 6 | port lincoln
# Processing Record 35 of Set 6 | mporokoso
# Processing Record 36 of Set 6 | sisimiut
# Processing Record 37 of Set 6 | mendeleyevsk
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | ostrovnoy
# Processing Record 40 of Set 6 | ahuimanu
# Processing Record 41 of Set 6 | izhma
# Processing Record 42 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 6 | paka
# Processing Record 44 of Set 6 | meulaboh
# Processing Record 45 of Set 6 | fremont
# Processing Record 46 of Set 6 | kieta
# Processing Record 47 of Set 6 | jeremie
# Processing Record 48 of Set 6 | manokwari
# Processing Record 49 of Set 6 | srednekolymsk
# Processing Record 50 of Set 6 | kologriv
# Processing Record 1 of Set 7 | nampula
# Processing Record 2 of Set 7 | storsteinnes
# Processing Record 3 of Set 7 | henzada
# City not found. Skipping...
# Processing Record 4 of Set 7 | alugan
# Processing Record 5 of Set 7 | inuvik
# Processing Record 6 of Set 7 | kimbe
# Processing Record 7 of Set 7 | sept-iles
# Processing Record 8 of Set 7 | canita
# Processing Record 9 of Set 7 | biak
# Processing Record 10 of Set 7 | hovd
# Processing Record 11 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | buala
# Processing Record 15 of Set 7 | natchitoches
# Processing Record 16 of Set 7 | larsnes
# Processing Record 17 of Set 7 | tilichiki
# Processing Record 18 of Set 7 | kaseda
# Processing Record 19 of Set 7 | benton harbor
# Processing Record 20 of Set 7 | abu zabad
# Processing Record 21 of Set 7 | luderitz
# Processing Record 22 of Set 7 | awbari
# Processing Record 23 of Set 7 | salina cruz
# Processing Record 24 of Set 7 | okhotsk
# Processing Record 25 of Set 7 | nha trang
# Processing Record 26 of Set 7 | kaeo
# Processing Record 27 of Set 7 | goya
# Processing Record 28 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 7 | kavieng
# Processing Record 30 of Set 7 | karachi
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | ottumwa
# Processing Record 33 of Set 7 | akyab
# Processing Record 34 of Set 7 | marabba
# Processing Record 35 of Set 7 | lima
# Processing Record 36 of Set 7 | kawalu
# Processing Record 37 of Set 7 | yuancheng
# Processing Record 38 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 7 | mwaro
# Processing Record 40 of Set 7 | iqaluit
# Processing Record 41 of Set 7 | korem
# Processing Record 42 of Set 7 | rameswaram
# Processing Record 43 of Set 7 | stokmarknes
# Processing Record 44 of Set 7 | yandoon
# City not found. Skipping...
# Processing Record 45 of Set 7 | alofi
# Processing Record 46 of Set 7 | fairbanks
# Processing Record 47 of Set 7 | porto belo
# Processing Record 48 of Set 7 | leningradskiy
# Processing Record 49 of Set 7 | quatre cocos
# Processing Record 50 of Set 7 | college
# Processing Record 1 of Set 8 | tumpat
# Processing Record 2 of Set 8 | ilulissat
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | khandyga
# Processing Record 5 of Set 8 | kaka
# Processing Record 6 of Set 8 | yining
# Processing Record 7 of Set 8 | berlevag
# Processing Record 8 of Set 8 | cabedelo
# Processing Record 9 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 10 of Set 8 | ekhabi
# Processing Record 11 of Set 8 | zhaoqing
# Processing Record 12 of Set 8 | vestmannaeyjar
# Processing Record 13 of Set 8 | matay
# Processing Record 14 of Set 8 | port elizabeth
# Processing Record 15 of Set 8 | baruun-urt
# Processing Record 16 of Set 8 | sinnamary
# Processing Record 17 of Set 8 | honiara
# Processing Record 18 of Set 8 | saint george
# Processing Record 19 of Set 8 | flin flon
# Processing Record 20 of Set 8 | orlik
# Processing Record 21 of Set 8 | mamallapuram
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | bonavista
# Processing Record 24 of Set 8 | chik
# Processing Record 25 of Set 8 | prince rupert
# Processing Record 26 of Set 8 | bethel
# Processing Record 27 of Set 8 | dong xoai
# Processing Record 28 of Set 8 | brahmapuri
# City not found. Skipping...
# Processing Record 29 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 30 of Set 8 | zaozerne
# Processing Record 31 of Set 8 | grand-lahou
# Processing Record 32 of Set 8 | camopi
# Processing Record 33 of Set 8 | mehamn
# Processing Record 34 of Set 8 | akom
# Processing Record 35 of Set 8 | plastun
# Processing Record 36 of Set 8 | telimele
# Processing Record 37 of Set 8 | miyako
# Processing Record 38 of Set 8 | yantal
# Processing Record 39 of Set 8 | odweyne
# Processing Record 40 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | san antonio
# Processing Record 42 of Set 8 | madikeri
# Processing Record 43 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 8 | mapiri
# Processing Record 45 of Set 8 | primero de marzo
# Processing Record 46 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 47 of Set 8 | christchurch
# Processing Record 48 of Set 8 | lisala
# Processing Record 49 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 8 | tuntum
# Processing Record 1 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 9 | kyaikkami
# Processing Record 3 of Set 9 | souillac
# Processing Record 4 of Set 9 | meadow lake
# Processing Record 5 of Set 9 | kulhudhuffushi
# Processing Record 6 of Set 9 | talnakh
# Processing Record 7 of Set 9 | kushima
# Processing Record 8 of Set 9 | mitsamiouli
# Processing Record 9 of Set 9 | fukue
# Processing Record 10 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 9 | grahamstown
# Processing Record 12 of Set 9 | mayor pablo lagerenza
# Processing Record 13 of Set 9 | beachwood
# Processing Record 14 of Set 9 | ambilobe
# Processing Record 15 of Set 9 | beloha
# Processing Record 16 of Set 9 | ambon
# Processing Record 17 of Set 9 | bull savanna
# Processing Record 18 of Set 9 | jacmel
# Processing Record 19 of Set 9 | andselv
# City not found. Skipping...
# Processing Record 20 of Set 9 | byron bay
# Processing Record 21 of Set 9 | camocim
# Processing Record 22 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 9 | ojinaga
# Processing Record 24 of Set 9 | springfield
# Processing Record 25 of Set 9 | alghero
# Processing Record 26 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 27 of Set 9 | darasun
# Processing Record 28 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 9 | road town
# Processing Record 30 of Set 9 | alashtar
# City not found. Skipping...
# Processing Record 31 of Set 9 | omsukchan
# Processing Record 32 of Set 9 | palmer
# Processing Record 33 of Set 9 | wukari
# Processing Record 34 of Set 9 | bayan
# Processing Record 35 of Set 9 | bucerias
# Processing Record 36 of Set 9 | ascension
# Processing Record 37 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 9 | antofagasta
# Processing Record 40 of Set 9 | lavrentiya
# Processing Record 41 of Set 9 | machico
# Processing Record 42 of Set 9 | inirida
# Processing Record 43 of Set 9 | red bluff
# Processing Record 44 of Set 9 | paita
# Processing Record 45 of Set 9 | morondava
# Processing Record 46 of Set 9 | north bend
# Processing Record 47 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 9 | huntsville
# Processing Record 49 of Set 9 | uddevalla
# Processing Record 50 of Set 9 | sabang
# Processing Record 1 of Set 10 | santa cruz
# Processing Record 2 of Set 10 | moose factory
# Processing Record 3 of Set 10 | yerbogachen
# Processing Record 4 of Set 10 | itarema
# Processing Record 5 of Set 10 | saint-pierre
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | mirnyy
# Processing Record 8 of Set 10 | guanare
# Processing Record 9 of Set 10 | mahanoro
# Processing Record 10 of Set 10 | xuzhou
# Processing Record 11 of Set 10 | fleetwood
# Processing Record 12 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 10 | ukiah
# Processing Record 14 of Set 10 | trairi
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | tadine
# Processing Record 17 of Set 10 | chebsara
# Processing Record 18 of Set 10 | dubti
# Processing Record 19 of Set 10 | coquimbo
# Processing Record 20 of Set 10 | thinadhoo
# Processing Record 21 of Set 10 | yulara
# Processing Record 22 of Set 10 | dzerzhinsk
# Processing Record 23 of Set 10 | parkes
# Processing Record 24 of Set 10 | beringovskiy
# Processing Record 25 of Set 10 | kloulklubed
# Processing Record 26 of Set 10 | issoire
# Processing Record 27 of Set 10 | codrington
# Processing Record 28 of Set 10 | pangnirtung
# Processing Record 29 of Set 10 | puerto penasco
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | fallon
# Processing Record 32 of Set 10 | harrisburg
# Processing Record 33 of Set 10 | gopalpur
# Processing Record 34 of Set 10 | gotsu
# Processing Record 35 of Set 10 | mugango
# Processing Record 36 of Set 10 | kununurra
# Processing Record 37 of Set 10 | kyabe
# Processing Record 38 of Set 10 | alihe
# Processing Record 39 of Set 10 | dudinka
# Processing Record 40 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 10 | myaundzha
# Processing Record 42 of Set 10 | salinas
# Processing Record 43 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 10 | korgen
# Processing Record 45 of Set 10 | maryville
# Processing Record 46 of Set 10 | kirkwall
# Processing Record 47 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 48 of Set 10 | san felipe
# Processing Record 49 of Set 10 | roebourne
# Processing Record 50 of Set 10 | alto araguaia
# Processing Record 1 of Set 11 | ingham
# Processing Record 2 of Set 11 | koulikoro
# Processing Record 3 of Set 11 | kashi
# Processing Record 4 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 11 | nola
# Processing Record 6 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 11 | pochutla
# Processing Record 8 of Set 11 | yabelo
# Processing Record 9 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 11 | nishihara
# Processing Record 11 of Set 11 | trapani
# Processing Record 12 of Set 11 | deputatskiy
# Processing Record 13 of Set 11 | honningsvag
# Processing Record 14 of Set 11 | whitehorse
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 11 | puerto asis
# Processing Record 18 of Set 11 | nautla
# Processing Record 19 of Set 11 | puerto narino
# Processing Record 20 of Set 11 | palestine
# Processing Record 21 of Set 11 | juazeiro
# Processing Record 22 of Set 11 | arlit
# Processing Record 23 of Set 11 | taoudenni
# Processing Record 24 of Set 11 | conceicao do araguaia
# Processing Record 25 of Set 11 | mont-dore
# Processing Record 26 of Set 11 | hami
# Processing Record 27 of Set 11 | tagab
# Processing Record 28 of Set 11 | port blair
# Processing Record 29 of Set 11 | gongzhuling
# Processing Record 30 of Set 11 | duliby
# Processing Record 31 of Set 11 | kalininsk
# Processing Record 32 of Set 11 | nouadhibou
# Processing Record 33 of Set 11 | tabuk
# Processing Record 34 of Set 11 | sterling
# Processing Record 35 of Set 11 | jiayuguan
# Processing Record 36 of Set 11 | ballitoville
# Processing Record 37 of Set 11 | kjopsvik
# Processing Record 38 of Set 11 | upleta
# Processing Record 39 of Set 11 | olinda
# Processing Record 40 of Set 11 | arman
# Processing Record 41 of Set 11 | vryburg
# Processing Record 42 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 11 | watertown
# Processing Record 44 of Set 11 | emba
# Processing Record 45 of Set 11 | peniche
# Processing Record 46 of Set 11 | tual
# Processing Record 47 of Set 11 | iberia
# Processing Record 48 of Set 11 | roma
# Processing Record 49 of Set 11 | isla vista
# Processing Record 50 of Set 11 | korla
# Processing Record 1 of Set 12 | mahon
# Processing Record 2 of Set 12 | salalah
# Processing Record 3 of Set 12 | metkovic
# Processing Record 4 of Set 12 | shubarkuduk
# Processing Record 5 of Set 12 | tazovskiy
# Processing Record 6 of Set 12 | nanortalik
# Processing Record 7 of Set 12 | mujiayingzi
# Processing Record 8 of Set 12 | tsiroanomandidy
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | seydisehir
# Processing Record 11 of Set 12 | sungairaya
# Processing Record 12 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 12 | vallee-jonction
# City not found. Skipping...
# Processing Record 14 of Set 12 | paamiut
# Processing Record 15 of Set 12 | sao felix do xingu
# Processing Record 16 of Set 12 | mirandopolis
# Processing Record 17 of Set 12 | tukrah
# Processing Record 18 of Set 12 | montefiascone
# Processing Record 19 of Set 12 | the valley
# Processing Record 20 of Set 12 | sechura
# Processing Record 21 of Set 12 | uray
# Processing Record 22 of Set 12 | merauke
# Processing Record 23 of Set 12 | helmsdale
# Processing Record 24 of Set 12 | talara
# Processing Record 25 of Set 12 | juruti
# Processing Record 26 of Set 12 | shyroke
# Processing Record 27 of Set 12 | myingyan
# Processing Record 28 of Set 12 | ketchikan
# Processing Record 29 of Set 12 | terrace
# Processing Record 30 of Set 12 | rey bouba
# Processing Record 31 of Set 12 | yakima
# Processing Record 32 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 12 | kalakamati
# Processing Record 34 of Set 12 | gospic
# Processing Record 35 of Set 12 | marzuq
# Processing Record 36 of Set 12 | simao
# Processing Record 37 of Set 12 | mangan
# Processing Record 38 of Set 12 | emerald
# Processing Record 39 of Set 12 | dongkan
# Processing Record 40 of Set 12 | rio gallegos
# Processing Record 41 of Set 12 | necochea
# Processing Record 42 of Set 12 | chillicothe
# Processing Record 43 of Set 12 | plettenberg bay
# Processing Record 44 of Set 12 | avera
# Processing Record 45 of Set 12 | pavlohrad
# Processing Record 46 of Set 12 | khuzhir
# Processing Record 47 of Set 12 | yuci
# Processing Record 48 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 12 | ust-uda
# Processing Record 50 of Set 12 | aloleng
# Processing Record 1 of Set 13 | broken hill
# Processing Record 2 of Set 13 | mogadishu
# Processing Record 3 of Set 13 | nea mikhaniona
# City not found. Skipping...
# Processing Record 4 of Set 13 | ixtapa
# Processing Record 5 of Set 13 | smoky lake
# Processing Record 6 of Set 13 | vostok
# Processing Record 7 of Set 13 | chitral
# Processing Record 8 of Set 13 | lagos
# Processing Record 9 of Set 13 | kamenka
# Processing Record 10 of Set 13 | fjerritslev
# Processing Record 11 of Set 13 | muisne
# Processing Record 12 of Set 13 | itanagar
# Processing Record 13 of Set 13 | suhbaatar
# Processing Record 14 of Set 13 | boyolangu
# Processing Record 15 of Set 13 | ambovombe
# Processing Record 16 of Set 13 | key west
# Processing Record 17 of Set 13 | hirara
# Processing Record 18 of Set 13 | takhtamygda
# Processing Record 19 of Set 13 | binga
# Processing Record 20 of Set 13 | sur
# Processing Record 21 of Set 13 | kolar
# Processing Record 22 of Set 13 | aviles
# Processing Record 23 of Set 13 | oxford
# Processing Record 24 of Set 13 | acapulco
# Processing Record 25 of Set 13 | kropotkin
# Processing Record 26 of Set 13 | chkalovskoye
# Processing Record 27 of Set 13 | tahe
# Processing Record 28 of Set 13 | karasburg
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | san cristobal
# Processing Record 31 of Set 13 | benghazi
# Processing Record 32 of Set 13 | lefka
# Processing Record 33 of Set 13 | port macquarie
# Processing Record 34 of Set 13 | homer
# Processing Record 35 of Set 13 | sao jose da coroa grande
# Processing Record 36 of Set 13 | comodoro rivadavia
# Processing Record 37 of Set 13 | imbituba
# Processing Record 38 of Set 13 | tocopilla
# Processing Record 39 of Set 13 | anna paulowna
# Processing Record 40 of Set 13 | hecun
# Processing Record 41 of Set 13 | navrongo
# Processing Record 42 of Set 13 | omboue
# Processing Record 43 of Set 13 | visnes
# Processing Record 44 of Set 13 | daru
# Processing Record 45 of Set 13 | mangai
# Processing Record 46 of Set 13 | sayalgudi
# City not found. Skipping...
# Processing Record 47 of Set 13 | longyearbyen
# Processing Record 48 of Set 13 | champerico
# Processing Record 49 of Set 13 | namatanai
# Processing Record 50 of Set 13 | lar
# Processing Record 1 of Set 14 | guane
# Processing Record 2 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 3 of Set 14 | golden gate
# Processing Record 4 of Set 14 | port-gentil
# Processing Record 5 of Set 14 | aguimes
# Processing Record 6 of Set 14 | havelock
# Processing Record 7 of Set 14 | chabahar
# Processing Record 8 of Set 14 | port moresby
# Processing Record 9 of Set 14 | zehdenick
# Processing Record 10 of Set 14 | la macarena
# Processing Record 11 of Set 14 | santa vitoria do palmar
# Processing Record 12 of Set 14 | atasu
# Processing Record 13 of Set 14 | dingle
# Processing Record 14 of Set 14 | jishui
# Processing Record 15 of Set 14 | madhupur
# Processing Record 16 of Set 14 | barcelos
# Processing Record 17 of Set 14 | margate
# Processing Record 18 of Set 14 | karasjok
# Processing Record 19 of Set 14 | vuktyl
# Processing Record 20 of Set 14 | pemberton
# Processing Record 21 of Set 14 | mabaruma
# Processing Record 22 of Set 14 | bakaly
# Processing Record 23 of Set 14 | chumikan
# Processing Record 24 of Set 14 | evensk
# Processing Record 25 of Set 14 | loralai
# Processing Record 26 of Set 14 | tamala
# Processing Record 27 of Set 14 | billings
# Processing Record 28 of Set 14 | laramie
# Processing Record 29 of Set 14 | maceio
# Processing Record 30 of Set 14 | bartica
# Processing Record 31 of Set 14 | alakurtti
# Processing Record 32 of Set 14 | chase
# Processing Record 33 of Set 14 | puerto baquerizo moreno
# Processing Record 34 of Set 14 | tigil
# Processing Record 35 of Set 14 | turukhansk
# Processing Record 36 of Set 14 | leh
# Processing Record 37 of Set 14 | bilma
# Processing Record 38 of Set 14 | tolmachevo
# Processing Record 39 of Set 14 | nuuk
# Processing Record 40 of Set 14 | pemba
# Processing Record 41 of Set 14 | seminole
# Processing Record 42 of Set 14 | xai-xai
# Processing Record 43 of Set 14 | yatou
# Processing Record 44 of Set 14 | taian
# Processing Record 45 of Set 14 | komsomolskiy
# Processing Record 46 of Set 14 | sibolga
# Processing Record 47 of Set 14 | tucuman
# Processing Record 48 of Set 14 | luena
# Processing Record 49 of Set 14 | sobolevo
# Processing Record 50 of Set 14 | henties bay
# Processing Record 1 of Set 15 | port pirie
# Processing Record 2 of Set 15 | prince george
# Processing Record 3 of Set 15 | faya
# Processing Record 4 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 15 | kutahya
# Processing Record 6 of Set 15 | shestakovo
# Processing Record 7 of Set 15 | abu samrah
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | henderson
# Processing Record 10 of Set 15 | siljan
# Processing Record 11 of Set 15 | mount isa
# Processing Record 12 of Set 15 | novougolnyy
# City not found. Skipping...
# Processing Record 13 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 15 | high level
# Processing Record 15 of Set 15 | imeni zhelyabova
# Processing Record 16 of Set 15 | japura
# Processing Record 17 of Set 15 | balkanabat
# Processing Record 18 of Set 15 | sola
# Processing Record 19 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 15 | petrokamenskoye
# Processing Record 21 of Set 15 | antalaha
# Processing Record 22 of Set 15 | igarapava
# Processing Record 23 of Set 15 | klaksvik
# Processing Record 24 of Set 15 | baturaja
# Processing Record 25 of Set 15 | that phanom
# Processing Record 26 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 15 | sri aman
# Processing Record 28 of Set 15 | bauchi
# Processing Record 29 of Set 15 | lianzhou
# Processing Record 30 of Set 15 | vao
# Processing Record 31 of Set 15 | barcelona
# Processing Record 32 of Set 15 | nanyamba
# Processing Record 33 of Set 15 | hamamatsu
# Processing Record 34 of Set 15 | pangkalanbuun
# Processing Record 35 of Set 15 | presidencia roque saenz pena
# Processing Record 36 of Set 15 | luancheng
# Processing Record 37 of Set 15 | ca mau
# Processing Record 38 of Set 15 | khoy
# Processing Record 39 of Set 15 | aras
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 670

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     71.55        98          62
# 1         Tuzha  57.6062   47.9360     19.49        95         100
# 2        Hobart -42.8794  147.3294     74.26        67          20
# 3         Bluff -46.6000  168.3333     54.75        65           4
# 4           Oga  46.4631   10.3470     43.03        78         100
# 5       Zhangye  38.9342  100.4517     27.16        30          15
# 6  Richards Bay -28.7830   32.0377     75.54        62          44
# 7      Hermanus -34.4187   19.2345     76.80        55          31
# 8         Airai  -8.9266  125.4092     62.64        94         100
# 9        Atuona  -9.8000 -139.0333     77.88        69           2
#
#    Wind Speed Country Current Description
# 0        1.01      EC              Clouds
# 1       11.45      RU                Snow
# 2       18.41      AU              Clouds
# 3       15.57      NZ               Clear
# 4        3.94      IT              Clouds
# 5       10.22      CN              Clouds
# 6       10.00      ZA              Clouds
# 7       16.96      ZA              Clouds
# 8        6.67      TL              Clouds
# 9       18.70      PF               Clear

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                              City Country      Lat       Lng  Max Temp  \
# 0                    Puerto Ayora      EC  -0.7393  -90.3518     71.55
# 1                           Tuzha      RU  57.6062   47.9360     19.49
# 2                          Hobart      AU -42.8794  147.3294     74.26
# 3                           Bluff      NZ -46.6000  168.3333     54.75
# 4                             Oga      IT  46.4631   10.3470     43.03
# ..                            ...     ...      ...       ...       ...
# 665  Presidencia Roque Saenz Pena      AR -26.7852  -60.4388     75.40
# 666                     Luancheng      CN  37.8792  114.6517     48.36
# 667                        Ca Mau      VN   9.1769  105.1500     83.55
# 668                          Khoy      IR  38.5504   44.9535     37.92
# 669                          Aras      ES  42.5617   -2.3560     47.75
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          98          62        1.01              Clouds
# 1          95         100       11.45                Snow
# 2          67          20       18.41              Clouds
# 3          65           4       15.57               Clear
# 4          78         100        3.94              Clouds
# ..        ...         ...         ...                 ...
# 665        44         100        5.68              Clouds
# 666        19           0        2.57               Clear
# 667        48         100        5.21              Clouds
# 668        48           0        2.30               Clear
# 669        93           0        3.44               Clear
#
# [670 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database")
